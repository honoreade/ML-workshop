# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

path  = 'Mall_Customers.csv'
readfile = pd.read_csv(path)

# # readfile.shape

readfile = readfile.drop('Gender', axis=1)
readfile = readfile.drop('CustomerID', axis=1)
# readfile.head(12)


X = readfile.drop(columns = ['Spending Score (1-100)'])
y = readfile['Spending Score (1-100)']

# mymodel = DecisionTreeClassifier()
# mymodel.fit(X,y)

# suggestions = mymodel.predict([[33,100]])
# suggestions

# readfile.columns



#####################################################

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(random_state=1)
model.fit(X,y)

readfile.hist(bins = 50, figsize = (20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Annual Income (k$)'}>],
#        [<AxesSubplot:title={'center':'Spending Score (1-100)'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

path  = 'headbrain1.csv'
readfile = pd.read_csv(path)
readfile.info()

# # readfile.shape
# readfile.head(12)


# X = readfile.drop(columns = ['Brain Weight(grams)'])
# y = readfile['Brain Weight(grams)']

# mymodel = DecisionTreeClassifier()
# mymodel.fit(X,y)

# suggestions = mymodel.predict([[4480]])
# suggestions
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Head Size(cm^3)      237 non-null    int64
#  1   Brain Weight(grams)  237 non-null    int64
# dtypes: int64(2)
# memory usage: 3.8 KB
